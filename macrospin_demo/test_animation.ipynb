# %% [markdown]
# # Test Animated 3D plotting

# %% [markdown]
# ## 1. Animated 2D

# %%
import numpy as np
import time
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
# %matplotlib notebook

# %%
"""
A simple example of an animated plot
From: https://matplotlib.org/examples/animation/simple_anim.html
"""
fig, ax = plt.subplots()

x = np.arange(0, 2*np.pi, 0.01)
line, = ax.plot(x, np.sin(x))


def animate(i):
    line.set_ydata(np.sin(x + i/10.0))  # update the data
    return line,


# Init only required for blitting to give a clean slate.
def init():
    line.set_ydata(np.ma.array(x, mask=True))
    return line,

ani = animation.FuncAnimation(fig, animate, np.arange(1, 200), init_func=init,
                              interval=25, repeat=False, blit=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# A variation
plt.close()
fig, ax = plt.subplots()

x = np.arange(0, 2*np.pi, 0.01)
y = np.sin(x)
xdata = []
ydata = []
line, = ax.plot(xdata,ydata)
ax.set_xlim(min(x),max(x))
ax.set_ylim(min(y),max(y))

def animate(i):
    xdata.append(x[i])
    ydata.append(y[i])
    line.set_xdata(xdata)
    line.set_ydata(ydata)
#     ax.autoscale()
    return line,


# Init only required for blitting to give a clean slate.
def init():
    line.set_ydata(ydata)
    return line,

ani = animation.FuncAnimation(fig, animate, np.arange(0, len(x)), init_func=init,
                              interval=10, repeat=False, blit=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## 2. Animated 3D

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
# Sample 3D plot, from: https://matplotlib.org/mpl_toolkits/mplot3d/tutorial.html
plt.close()
fig = plt.figure()
ax = fig.gca(projection='3d')
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)
ax.plot(x, y, z, label='parametric curve')
ax.legend()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Animated version
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)
plt.close()
fig = plt.figure()
ax = fig.gca(projection='3d')
xdata = []
ydata = []
zdata = []
line, = ax.plot(xdata, ydata, zdata, label='parametric curve', color='b')
ax.legend()
ax.set_xlabel("X")
ax.set_zlabel("Z")
ax.set_xlim3d(min(x),max(x))
ax.set_ylim3d(min(y),max(y))
ax.set_zlim3d(min(z),max(z))

def animate(i):
#     ax.cla()
#     ax.lines[-1].remove()
    for line in ax.lines:
        line.remove()
    xdata.append(x[i])
    ydata.append(y[i])
    zdata.append(z[i])
#     ax.lines.pop(-1)
    line, = ax.plot(xdata, ydata, zdata, color='b')
    ax.plot([xdata[-1]],[ydata[-1]],[zdata[-1]],marker='o',color='r')
    plt.draw()
    return line,


# Init only required for blitting to give a clean slate.
def init():
#     ax.clear()
#     ax.set_xlim3d(min(x),max(x))
#     ax.set_ylim3d(min(y),max(y))
#     ax.set_zlim3d(min(z),max(z))     
#     ax.lines[-1].remove()
    return line,

ani = animation.FuncAnimation(fig, animate, np.arange(0, len(x)), init_func=init, 
                              interval=10, repeat=False, blit=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
l = ax.lines[0]

# %%
# l.get_xydata()
l.set_data?

# %%
l.get_xdata()
# x
# Out:
# array([ 3.29478307e-02,  4.09895726e-02,  4.56870559e-02,  4.68474648e-02,
#         4.45022944e-02,  3.89216221e-02,  3.06067895e-02,  2.02565116e-02,
#         8.70688513e-03, -3.14777057e-03, -1.44411051e-02, -2.44138941e-02,
#        -3.24741754e-02, -3.82315231e-02, -4.15047600e-02, -4.23074678e-02,
#        -4.08184035e-02, -3.73442881e-02, -3.22810855e-02, -2.60777979e-02,
#        -1.92047546e-02, -1.21268198e-02, -5.28103909e-03,  9.42059547e-04,
#         6.21416151e-03,  1.02820947e-02,  1.29777270e-02,  1.42241289e-02,
#         1.40370714e-02,  1.25210087e-02,  9.85912231e-03,  6.29770065e-03,
#         2.12596417e-03, -2.34680702e-03, -6.81452233e-03, -1.09955414e-02,
#        -1.46499646e-02, -1.75916752e-02, -1.96946937e-02, -2.08941857e-02,
#        -2.11830414e-02, -2.06052573e-02, -1.92474001e-02, -1.72292892e-02,
#        -1.46947736e-02, -1.18031768e-02, -8.72169927e-03, -5.61882781e-03,
#        -2.65863230e-03,  4.27861346e-06,  2.22941071e-03,  3.89489639e-03,
#         4.90204323e-03,  5.17997528e-03,  4.69026349e-03,  3.43125854e-03,
#         1.44165771e-03, -1.19731006e-03, -4.36176905e-03, -7.88779957e-03,
#        -1.15772280e-02, -1.52067569e-02, -1.85401704e-02, -2.13428989e-02,
#        -2.33978385e-02, -2.45210826e-02, -2.45761908e-02, -2.34858081e-02,
#        -2.12397981e-02, -1.78994794e-02, -1.35979504e-02, -8.53676014e-03,
#        -2.97928995e-03,  2.75886017e-03,  8.32238245e-03,  1.33318188e-02,
#         1.74025039e-02,  2.01672434e-02,  2.13027844e-02,  2.05594425e-02,
#         1.77921396e-02,  1.29896926e-02,  6.29780557e-03, -1.96962918e-03,
#        -1.13360032e-02, -2.11874217e-02, -3.08178338e-02, -3.94893758e-02,
#        -4.64997196e-02, -5.12463788e-02, -5.32787128e-02, -5.23315349e-02,
#        -4.83386079e-02, -4.14284162e-02, -3.19072973e-02, -2.02358352e-02,
#        -7.00360604e-03,  7.09451335e-03,  2.12795901e-02,  3.47088719e-02])

# %% [markdown]
# ### Save animation as movie

# %%
plt.rcParams['animation.ffmpeg_path'] = '/usr/local/bin/ffmpeg'

# %%
ani.to_html5_video()
# Out:
# '<video width="640" height="480" controls autoplay>\n  <source type="video/mp4" src="...\\ndQgvUHCxJY ...

# %%
FFwriter = animation.FFMpegWriter(fps=30,extra_args=['-vcodec','libxvid','-r','25'])
# (fps=30, extra_args=['-vcodec', 'libx264'])
ani.save('sample_animation.mp4', writer = FFwriter)

# %%
Writer = animation.writers['ffmpeg']
writer3 = Writer(fps=1, extra_args=['-r', '25'])
ani.save('sample_animation.mp4', writer = writer3)

# %%
animation.writers

# %% [markdown]
# ## 3. Animation with multi-panes

# %%
plt.close()
fig, (ax1,ax2) = plt.subplots(1,2)

x = np.arange(0, 2*np.pi, 0.01)
y1 = np.sin(x)
y2 = np.cos(x)
xdata = []
ydata1 = []
ydata2 = []
line1, = ax1.plot(xdata,ydata1)
line2, = ax2.plot(xdata,ydata2)
ax1.set_xlim(min(x),max(x))
ax1.set_ylim(min(y1),max(y1))
ax2.set_xlim(min(x),max(x))
ax2.set_ylim(min(y2),max(y2))

def animate(i):
    xdata.append(x[i])
    ydata1.append(y1[i])
    ydata2.append(y2[i])
    line1.set_xdata(xdata)
    line1.set_ydata(ydata1)
    line2.set_xdata(xdata)
    line2.set_ydata(ydata2)
#     ax.autoscale()
    return True


# Init only required for blitting to give a clean slate.
def init():
    pass
    return True

ani = animation.FuncAnimation(fig, animate, np.arange(0, len(x)), init_func=init,
                              interval=40, repeat=False, blit=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## 4. Animation class

# %%
import test_animation
import importlib

# %%
importlib.reload(test_animation)
xs = np.linspace(-1,1,100)
thetas = np.arccos(xs)
phis = np.arcsin(xs)
ani = test_animation.SpinAnimation([thetas,phis],average=1,view='xyz')

# %%
ani.init_figure(figsize=(10,8))
ani.animate()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
xs = np.linspace(-6,6,100)
ys = np.sin(xs)
zs = np.cos(xs)
ani = test_animation.SpinAnimation([xs,ys,zs],average=1,view='angle')

# %%
ani.view = "angle"
ani.init_figure(figsize=(10,8))
ani.animate()
# Out:
# <img src="data:image/png;base64,..." width="1000">
